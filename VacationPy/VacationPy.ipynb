# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json
from pprint import pprint

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0        0  fale old settlement  -9.3852 -171.2468     28.30        74
# 1        1               kodiak  57.7900 -152.4072     12.73        82
# 2        2            grytviken -54.2811  -36.5092    -15.48        76
# 3        3            adamstown -25.0660 -130.1015     22.34        78
# 4        4        port mathurin -19.6833   63.4167     22.49        73
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        7.44      TK  1723166134
# 1         100        2.57      US  1723166135
# 2          15        6.55      GS  1723166136
# 3         100       12.38      PN  1723166138
# 4          54        9.54      MU  1723166139

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
plot = city_data_df.hvplot.scatter(
    x='Lng', 
    y='Lat', 
    size='Humidity',  
    hover_cols=['City', 'Humidity', 'Max Temp', 'Cloudiness'],
    title='City Humidity Levels',
    xlabel='Longitude',
    ylabel='Latitude',
    size_max=25,
    color='purple',
)

# Display the map
plot
# Out:
# WARNING:param.main: size_max option not found for scatter plot with bokeh; similar options include: ['size']
# :Scatter   [Lng]   (Lat,Humidity,City,Max Temp,Cloudiness)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_temp_min = 16  
ideal_temp_max = 25
ideal_humidity_max = 72
ideal_cloudiness_max = 15 

# Filter the DataFrame based on the defined conditions
ideal_weather_df = city_data_df[
    (city_data_df['Max Temp'] >= ideal_temp_min) &
    (city_data_df['Max Temp'] <= ideal_temp_max) &
    (city_data_df['Humidity'] <= ideal_humidity_max) &
    (city_data_df['Cloudiness'] <= ideal_cloudiness_max)
]

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display the filtered DataFrame
ideal_weather_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 10        10            semdinli  37.3051   44.5742     18.02        69
# 38        38         yellowknife  62.4560 -114.3525     24.12        51
# 92        92   palazzolo acreide  37.0623   14.9035     18.78        45
# 101      101            djambala  -2.5447   14.7533     19.44        72
# 105      105       alice springs -23.7000  133.8833     21.75        30
# 143      143               hotan  37.0997   79.9269     24.91        30
# 146      146         broken hill -31.9500  141.4333     16.07        42
# 160      160  sao felix do xingu  -6.6447  -51.9950     24.41        38
# 163      163   port saint john's -31.6229   29.5448     17.73        68
# 203      203         antsiranana -12.2787   49.2917     22.09        69
# 207      207           carnarvon -24.8667  113.6333     18.76        46
# 230      230             okhotsk  59.3833  143.3000     19.23        62
# 238      238          miles city  46.4083 -105.8406     21.54        35
# 246      246         port alfred -33.5906   26.8910     16.92        56
# 248      248             colonia  50.9333    6.9500     21.08        68
# 259      259              hinton  53.4001 -117.5857     22.65        38
# 301      301              kaliua  -5.0606   31.7936     19.15        46
# 306      306      guerrero negro  27.9769 -114.0611     24.30        60
# 318      318               kyren  51.6828  102.1408     19.69        65
# 349      349      nova xavantina -14.6667  -52.3500     23.12        36
# 381      381               lensk  60.7253  114.9278     23.70        57
# 395      395             farkhar  36.5729   69.8578     21.49        22
# 407      407        richards bay -28.7830   32.0377     22.45        32
# 417      417       ust'-barguzin  53.4500  108.9833     17.93        65
# 429      429              nyurba  63.2842  118.3319     22.74        41
# 454      454               labin  45.0950   14.1197     23.30        67
# 461      461              ulundi -28.3352   31.4162     20.16        28
# 468      468           taroudant  30.4703   -8.8770     23.64        53
# 477      477              miyaly  48.8844   53.7836     22.73        53
# 517      517    monte argentario  42.4345   11.1195     23.88        64
# 523      523            paracatu -17.2222  -46.8747     19.83        54
# 551      551            l'alcora  40.0667   -0.2000     24.01        58
#
#      Cloudiness  Wind Speed Country        Date
# 10            0        3.49      TR  1723166146
# 38            9        6.71      CA  1723165895
# 92            0        0.81      IT  1723166248
# 101           8        2.05      CG  1723166258
# 105           0        3.60      AU  1723166263
# 143           0        3.35      CN  1723166313
# 146           3        1.46      AU  1723166318
# 160           0        0.67      BR  1723166334
# 163           0        2.32      ZA  1723166338
# 203           6        7.34      MG  1723166390
# 207           0        5.80      AU  1723166394
# 230           7        2.49      RU  1723166422
# 238           0        3.60      US  1723166433
# 246           0        7.02      ZA  1723166442
# 248           0        3.09      DE  1723166445
# 259           5        3.85      CA  1723166459
# 301           5        2.07      TZ  1723166510
# 306           0        7.12      MX  1723166516
# 318           6        0.22      RU  1723166531
# 349           5        0.93      BR  1723166569
# 381          11        2.17      RU  1723166610
# 395           0        3.26      AF  1723166626
# 407           0        5.42      ZA  1723166392
# 417           0        0.18      RU  1723166653
# 429           3        0.72      RU  1723166668
# 454           0        3.60      HR  1723166698
# 461           1        3.63      ZA  1723166707
# 468           0        1.38      MA  1723166715
# 477           5        2.16      KZ  1723166726
# 517           0        4.63      IT  1723166780
# 523           4        0.99      BR  1723166788
# 551           8        1.33      ES  1723166823

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 10             semdinli      TR  37.3051   44.5742        69
# 38          yellowknife      CA  62.4560 -114.3525        51
# 92    palazzolo acreide      IT  37.0623   14.9035        45
# 101            djambala      CG  -2.5447   14.7533        72
# 105       alice springs      AU -23.7000  133.8833        30
# 143               hotan      CN  37.0997   79.9269        30
# 146         broken hill      AU -31.9500  141.4333        42
# 160  sao felix do xingu      BR  -6.6447  -51.9950        38
# 163   port saint john's      ZA -31.6229   29.5448        68
# 203         antsiranana      MG -12.2787   49.2917        69
# 207           carnarvon      AU -24.8667  113.6333        46
# 230             okhotsk      RU  59.3833  143.3000        62
# 238          miles city      US  46.4083 -105.8406        35
# 246         port alfred      ZA -33.5906   26.8910        56
# 248             colonia      DE  50.9333    6.9500        68
# 259              hinton      CA  53.4001 -117.5857        38
# 301              kaliua      TZ  -5.0606   31.7936        46
# 306      guerrero negro      MX  27.9769 -114.0611        60
# 318               kyren      RU  51.6828  102.1408        65
# 349      nova xavantina      BR -14.6667  -52.3500        36
# 381               lensk      RU  60.7253  114.9278        57
# 395             farkhar      AF  36.5729   69.8578        22
# 407        richards bay      ZA -28.7830   32.0377        32
# 417       ust'-barguzin      RU  53.4500  108.9833        65
# 429              nyurba      RU  63.2842  118.3319        41
# 454               labin      HR  45.0950   14.1197        67
# 461              ulundi      ZA -28.3352   31.4162        28
# 468           taroudant      MA  30.4703   -8.8770        53
# 477              miyaly      KZ  48.8844   53.7836        53
# 517    monte argentario      IT  42.4345   11.1195        64
# 523            paracatu      BR -17.2222  -46.8747        54
# 551            l'alcora      ES  40.0667   -0.2000        58

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# I've included these lines of code here to test my API code and navigate the Geoapify API
target_city = "semdinli"
base_url = "https://api.geoapify.com/v2/places"
base_url
#target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"
#target_url
# Out:
# 'https://api.geoapify.com/v2/places'

# %%
geo_data = requests.get(target_url).json()
pprint(geo_data)
# Out:
# {'query': {'parsed': {'city': 'semdinli', 'expected_type': 'unknown'},
#            'text': 'semdinli'},
#  'results': [{'address_line1': '30800 Şemdinli',
#               'address_line2': 'Turkey',
#               'bbox': {'lat1': 37.1438498,
#                        'lat2': 37.4703397,
#                        'lon1': 44.1988028,
#                        'lon2': 44.815191},
#               'category': 'administrative',
#               'city': 'Şemdinli',
#               'country': 'Turkey',
#               'country_code': 'tr',
#               'county': 'Hakkâri',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': '30800 Şemdinli, Turkey',
#               'lat': 37.3060554,
#               'lon': 44.5735617,
#               'place_id': '517cde43786a49464059d1e1c6d22ca74240f00101f901c614150000000000c0020792030833303830302b7472',
#               'plus_code': '8H968H4F+CC',
#               'plus_code_short': '4F+CC Şemdinli, Hakkâri, Turkey',
#               'postcode': '30800',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.45000999999999997,
#                        'match_type': 'full_match',
#                        'popularity': 1.2734926683844559},
#               'result_type': 'postcode',
#               'state': 'Eastern Anatolia Region',
#               'timezone': {'name': 'Europe/Istanbul',
#                            'offset_DST': '+03:00',
#                            'offset_DST_seconds': 10800,
#                            'offset_STD': '+03:00',
#                            'offset_STD_seconds': 10800}}]}

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"radius":radius, 
          "categories": "accommodation.hotel",
          "apiKey": geoapify_key,
          "limit": 10
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    name_address = requests.get(base_url,params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"] 
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# semdinli - nearest hotel: Vali Orhan Isin Hoteli
# yellowknife - nearest hotel: No hotel found
# palazzolo acreide - nearest hotel: Hotel Colle Acre
# djambala - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# broken hill - nearest hotel: Ibis Styles
# sao felix do xingu - nearest hotel: Hotel Terraço
# port saint john's - nearest hotel: Outback Inn
# antsiranana - nearest hotel: Central
# carnarvon - nearest hotel: No hotel found
# okhotsk - nearest hotel: No hotel found
# miles city - nearest hotel: Historic Olive Hotel
# port alfred - nearest hotel: No hotel found
# colonia - nearest hotel: Wasserturm Hotel Cologne
# hinton - nearest hotel: Timberland Hotel
# kaliua - nearest hotel: No hotel found
# guerrero negro - nearest hotel: Plaza sal paraiso
# kyren - nearest hotel: No hotel found
# nova xavantina - nearest hotel: Hotel Morada do Sol
# lensk - nearest hotel: No hotel found
# farkhar - nearest hotel: No hotel found
# richards bay - nearest hotel: SUN1 Richards Bay
# ust'-barguzin - nearest hotel: Байкальский бриз
# nyurba - nearest hotel: Марина
# labin - nearest hotel: Peteani
# ulundi - nearest hotel: Garden Court Ulundi
# taroudant - nearest hotel: Hotel Tiouit
# miyaly - nearest hotel: Ахан
# monte argentario - nearest hotel: Belvedere
# paracatu - nearest hotel: Hotel Presidente
# l'alcora - nearest hotel: No hotel found
#                    City Country      Lat       Lng  Humidity  \
# 10             semdinli      TR  37.3051   44.5742        69
# 38          yellowknife      CA  62.4560 -114.3525        51
# 92    palazzolo acreide      IT  37.0623   14.9035        45
# 101            djambala      CG  -2.5447   14.7533        72
# 105       alice springs      AU -23.7000  133.8833        30
# 143               hotan      CN  37.0997   79.9269        30
# 146         broken hill      AU -31.9500  141.4333        42
# 160  sao felix do xingu      BR  -6.6447  -51.9950        38
# 163   port saint john's      ZA -31.6229   29.5448        68
# 203         antsiranana      MG -12.2787   49.2917        69
# 207           carnarvon      AU -24.8667  113.6333        46
# 230             okhotsk      RU  59.3833  143.3000        62
# 238          miles city      US  46.4083 -105.8406        35
# 246         port alfred      ZA -33.5906   26.8910        56
# 248             colonia      DE  50.9333    6.9500        68
# 259              hinton      CA  53.4001 -117.5857        38
# 301              kaliua      TZ  -5.0606   31.7936        46
# 306      guerrero negro      MX  27.9769 -114.0611        60
# 318               kyren      RU  51.6828  102.1408        65
# 349      nova xavantina      BR -14.6667  -52.3500        36
# 381               lensk      RU  60.7253  114.9278        57
# 395             farkhar      AF  36.5729   69.8578        22
# 407        richards bay      ZA -28.7830   32.0377        32
# 417       ust'-barguzin      RU  53.4500  108.9833        65
# 429              nyurba      RU  63.2842  118.3319        41
# 454               labin      HR  45.0950   14.1197        67
# 461              ulundi      ZA -28.3352   31.4162        28
# 468           taroudant      MA  30.4703   -8.8770        53
# 477              miyaly      KZ  48.8844   53.7836        53
# 517    monte argentario      IT  42.4345   11.1195        64
# 523            paracatu      BR -17.2222  -46.8747        54
# 551            l'alcora      ES  40.0667   -0.2000        58
#
#                                           Hotel Name
# 10                            Vali Orhan Isin Hoteli
# 38                                    No hotel found
# 92                                  Hotel Colle Acre
# 101                                   No hotel found
# 105                             Aurora Alice Springs
# 143  Hua Yi International Hotel (accepts foreigners)
# 146                                      Ibis Styles
# 160                                    Hotel Terraço
# 163                                      Outback Inn
# 203                                          Central
# 207                                   No hotel found
# 230                                   No hotel found
# 238                             Historic Olive Hotel
# 246                                   No hotel found
# 248                         Wasserturm Hotel Cologne
# 259                                 Timberland Hotel
# 301                                   No hotel found
# 306                                Plaza sal paraiso
# 318                                   No hotel found
# 349                              Hotel Morada do Sol
# 381                                   No hotel found
# 395                                   No hotel found
# 407                                SUN1 Richards Bay
# 417                                 Байкальский бриз
# 429                                           Марина
# 454                                          Peteani
# 461                              Garden Court Ulundi
# 468                                     Hotel Tiouit
# 477                                             Ахан
# 517                                        Belvedere
# 523                                 Hotel Presidente
# 551                                   No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
vacation_plot = hotel_df.hvplot.scatter(
    x='Lng', 
    y='Lat', 
    size='Humidity',  
    hover_cols=['Hotel Name', 'Country'],
    title='Nearest Hotels',
    xlabel='Longitude',
    ylabel='Latitude',
    size_max=25,
    color='purple',
)

# Display the map
vacation_plot
# Out:
# WARNING:param.main: size_max option not found for scatter plot with bokeh; similar options include: ['size']
# :Scatter   [Lng]   (Lat,Humidity,Hotel Name,Country)
